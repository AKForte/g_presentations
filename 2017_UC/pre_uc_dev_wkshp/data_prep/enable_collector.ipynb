# %%
from arcgis.gis import *

# %%
gis = GIS("https://python.playground.esri.com/portal","atma.mani","am4272017")

# %%
wm = gis.content.search("owner:atma.mani","web map")[0]
wm
# Out:
# <Item title:"damange map" type:Web Map owner:atma.mani>

# %%
wm.typeKeywords
# Out:
# ['ArcGIS Online',
#  'Explorer Web Map',
#  'Map',
#  'OfflineDisabled',
#  'Online Map',
#  'Web Map']

# %%
wm.update({'typeKeywords':wm.typeKeywords.append("Collector")})
# Out:
# True

# %%
wm.typeKeywords
# Out:
# ['ArcGIS Online',
#  'Explorer Web Map',
#  'Map',
#  'OfflineDisabled',
#  'Online Map',
#  'Web Map']
